# %%
import tpot
print(tpot.__version__)
# Out:
# c:\Users\souha\Downloads\Human Centered AutoML Thesis\.venv\Lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")
# 0.12.2

# %%
from src.tpot_experiments import run_tpot_experiment

test_result = run_tpot_experiment(
    dataset_name="breast_cancer",
    seed=42,
)

test_result
# Out:
# Running TPOT: breast_cancer | seed 42
# Optimization Progress:   0%|          | 0/100 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9811844295188893
#
# Generation 2 - Current best internal CV score: 0.9812635111075929
#
# Generation 3 - Current best internal CV score: 0.9812635111075929
#
# Generation 4 - Current best internal CV score: 0.9836031442454629
#
# Generation 5 - Current best internal CV score: 0.9836031442454629
#
# Generation 6 - Current best internal CV score: 0.9836054105755505
#
# Generation 7 - Current best internal CV score: 0.9836054105755505
#
# 10.17 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# ...

# %%
from src.tpot_experiments import run_all_tpot_experiments

tpot_results = run_all_tpot_experiments()

tpot_results
# Out:
# Running TPOT: breast_cancer | seed 42
# Optimization Progress:   0%|          | 0/100 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9811844295188893
#
# Generation 2 - Current best internal CV score: 0.9812635111075929
#
# Generation 3 - Current best internal CV score: 0.9812635111075929
#
# Generation 4 - Current best internal CV score: 0.9836031442454629
#
# Generation 5 - Current best internal CV score: 0.9836031442454629
#
# Generation 6 - Current best internal CV score: 0.9836054105755505
#
# Generation 7 - Current best internal CV score: 0.9836054105755505
#
# 463.39 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# ...

# %%
from src.tpot_experiments import run_all_tpot_experiments

tpot_results = run_all_tpot_experiments()

tpot_results
# Out:
# Running TPOT: breast_cancer | seed 42
# Optimization Progress:   0%|          | 0/100 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.9811844295188893
#
# Generation 2 - Current best internal CV score: 0.9812635111075929
#
# Generation 3 - Current best internal CV score: 0.9812635111075929
#
# Generation 4 - Current best internal CV score: 0.9836031442454629
#
# Generation 5 - Current best internal CV score: 0.9836031442454629
#
# Generation 6 - Current best internal CV score: 0.9836054105755505
#
# Generation 7 - Current best internal CV score: 0.9836054105755505
#
# 10.18 minutes have elapsed. TPOT will close down.
# TPOT closed during evaluation in one generation.
# WARNING: TPOT may not provide a good pipeline if TPOT is stopped/interrupted in a early generation.
#
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# ...
